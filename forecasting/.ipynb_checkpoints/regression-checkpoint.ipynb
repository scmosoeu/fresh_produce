# %%
import pandas as pd
import numpy as np
import requests
import urllib

from sqlalchemy import create_engine

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Connection to RDS
server_info = 'DRIVER={SQL Server};SERVER=incubate-inventory-management.cnzbp4ndrpos.eu-west-1.rds.amazonaws.com,1433;DATABASE=Fresh_Produce_Market_Data;UID=admin;PWD=fXToh9AXt30Yi7dGdlI2'

# %%
# Creating a connection to MS SQL SERVER
params = urllib.parse.quote_plus(server_info)
engine = create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)
connection = engine.connect()

# %%
# Upload sales data
sales = pd.read_sql_table(
    table_name='Durban_Fresh_produce_market',
    con=connection,
    parse_dates=['Date']
)

# %% [markdown]
# ## Data preparation

# %%
# Check the first five rows
sales.head()
# Out:
#               Commodities Weight_Kg Size_Grade Container           Province  \
# 0  APPLE GOLDEN DELICIOUS      9.00         2S     JE090               CAPE
# 1  APPLE GOLDEN DELICIOUS      9.00         2S     JE090  ORANGE FREE STATE
# 2  APPLE GOLDEN DELICIOUS      9.00         2S     JE090              NATAL
# 3  APPLE GOLDEN DELICIOUS      9.00         2U     JE090               CAPE
# 4  APPLE GOLDEN DELICIOUS     18.30         2X     M4183               CAPE
#
#   Low_Price High_Price Average_Price Sales_Total Total_Qty_Sold Total_Kg_Sold  \
# 0     50.00     100.00         51.39        9250            180          1620
# 1      0.00       0.00          0.00           0              0             0
# 2     10.00      10.00         10.00          30              3            27
# 3     50.00      50.00         50.00        9000            180          1620
# 4      0.00       0.00          0.00           0              0             0
#
#   Stock_On_Hand       Date
# 0          1397 2020-02-26
# 1            80 2020-02-26
# 2             6 2020-02-26
# 3             0 2020-02-26
# 4             1 2020-02-26

# %%
# View datatype of each column
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151571 entries, 0 to 151570
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Commodities     151571 non-null  object
#  1   Weight_Kg       151571 non-null  object
#  2   Size_Grade      151571 non-null  object
#  3   Container       151571 non-null  object
#  4   Province        151571 non-null  object
#  5   Low_Price       151571 non-null  object
#  6   High_Price      151571 non-null  object
#  7   Average_Price   151571 non-null  object
#  8   Sales_Total     151571 non-null  object
#  9   Total_Qty_Sold  151571 non-null  object
#  10  Total_Kg_Sold   151571 non-null  object
#  11  Stock_On_Hand   151571 non-null  object
#  12  Date            151571 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(12)
# memory usage: 15.0+ MB

# %%
# Convert some of the columns to their appropriate data type
float_columns = ['Weight_Kg', 'Low_Price', 'High_Price', 'Average_Price', 
                 'Sales_Total', 'Total_Kg_Sold', 'Total_Qty_Sold', 'Stock_On_Hand']


# Convert the columns to numeric
for col in float_columns:
    # sales[col] = sales[col].astype(float)
    sales[col] = pd.to_numeric(sales[col])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151571 entries, 0 to 151570
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Commodities     151571 non-null  object
#  1   Weight_Kg       151571 non-null  float64
#  2   Size_Grade      151571 non-null  object
#  3   Container       151571 non-null  object
#  4   Province        151571 non-null  object
#  5   Low_Price       151571 non-null  float64
#  6   High_Price      151571 non-null  float64
#  7   Average_Price   151571 non-null  float64
#  8   Sales_Total     151570 non-null  float64
#  9   Total_Qty_Sold  151570 non-null  float64
#  10  Total_Kg_Sold   151571 non-null  float64
#  11  Stock_On_Hand   151570 non-null  float64
#  12  Date            151571 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(8), object(4)
# memory usage: 15.0+ MB

# %%
sales.head()
# Out:
#               Commodities  Weight_Kg Size_Grade Container           Province  \
# 0  APPLE GOLDEN DELICIOUS        9.0         2S     JE090               CAPE
# 1  APPLE GOLDEN DELICIOUS        9.0         2S     JE090  ORANGE FREE STATE
# 2  APPLE GOLDEN DELICIOUS        9.0         2S     JE090              NATAL
# 3  APPLE GOLDEN DELICIOUS        9.0         2U     JE090               CAPE
# 4  APPLE GOLDEN DELICIOUS       18.3         2X     M4183               CAPE
#
#    Low_Price  High_Price  Average_Price  Sales_Total  Total_Qty_Sold  \
# 0       50.0       100.0          51.39       9250.0           180.0
# 1        0.0         0.0           0.00          0.0             0.0
# 2       10.0        10.0          10.00         30.0             3.0
# 3       50.0        50.0          50.00       9000.0           180.0
# 4        0.0         0.0           0.00          0.0             0.0
#
#    Total_Kg_Sold  Stock_On_Hand       Date
# 0         1620.0         1397.0 2020-02-26
# 1            0.0           80.0 2020-02-26
# 2           27.0            6.0 2020-02-26
# 3         1620.0            0.0 2020-02-26
# 4            0.0            1.0 2020-02-26

# %%
# Check for the number of days in the database
print(f"{sales['Date'].nunique()} days recorded in the database")
# Out:
# 147 days recorded in the database

# %%
# Remove days whereby total sales equal 0 because it registers average_price as zero.
filtered_sales = sales[sales['Sales_Total'] != 0]

# %%
print(f"{filtered_sales['Date'].nunique()} days recorded in the database")
# Out:
# 147 days recorded in the database

# %% [markdown]
# Therefore no days were lost due to filtering by 'Sales_Total'

# %%
filtered_sales.head()
# Out:
#               Commodities  Weight_Kg Size_Grade Container Province  Low_Price  \
# 0  APPLE GOLDEN DELICIOUS        9.0         2S     JE090     CAPE       50.0
# 2  APPLE GOLDEN DELICIOUS        9.0         2S     JE090    NATAL       10.0
# 3  APPLE GOLDEN DELICIOUS        9.0         2U     JE090     CAPE       50.0
# 7      APPLE GRANNY SMITH       12.0         1S     EC120     CAPE       60.0
# 8      APPLE GRANNY SMITH       12.0         1S     EC120     CAPE       60.0
#
#    High_Price  Average_Price  Sales_Total  Total_Qty_Sold  Total_Kg_Sold  \
# 0       100.0          51.39       9250.0           180.0         1620.0
# 2        10.0          10.00         30.0             3.0           27.0
# 3        50.0          50.00       9000.0           180.0         1620.0
# 7        60.0          60.00       6000.0           100.0         1200.0
# 8        96.0          62.30      13020.0           209.0         2508.0
#
#    Stock_On_Hand       Date
# 0         1397.0 2020-02-26
# 2            6.0 2020-02-26
# 3            0.0 2020-02-26
# 7          164.0 2020-02-26
# 8            0.0 2020-02-26

# %%
# Check PINEAPPLE commodity to observe daily sales
sales[(sales['Commodities'] == 'PINEAPPLE QUEEN VICTORIA') & (sales['Container'] == 'LM080') & (sales['Province'] == 'NATAL')].sort_values('Date').head(20)
# Out:
#                      Commodities  Weight_Kg Size_Grade Container Province  \
# 56030   PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 56031   PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 144875  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 144874  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 144873  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 144871  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 144872  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 144870  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 58744   PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 58745   PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 58746   PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 58747   PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 58743   PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 58748   PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 145590  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 145582  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 145585  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 145586  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 145587  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
# 145580  PINEAPPLE QUEEN VICTORIA        8.0                LM080    NATAL
#
#         Low_Price  High_Price  Average_Price  Sales_Total  Total_Qty_Sold  \
# 56030        85.0        85.0          85.00        340.0             4.0
# 56031        75.0        75.0          75.00       1125.0            15.0
# 144875       60.0        85.0          61.89      21784.0           352.0
# 144874       40.0        40.0          40.00       1760.0            44.0
# 144873       56.0        56.0          56.00       7448.0           133.0
# 144871       56.0        75.0          74.87      56830.0           759.0
# 144872       65.0        65.0          65.00      29120.0           448.0
# 144870       85.0        85.0          85.00      74120.0           872.0
# 58744        75.0        75.0          75.00      14400.0           192.0
# 58745        65.0        65.0          65.00       7085.0           109.0
# 58746        56.0        56.0          56.00       3976.0            71.0
# 58747        40.0        40.0          40.00         40.0             1.0
# 58743        85.0        85.0          85.00       7140.0            84.0
# 58748        72.0        85.0          73.01       6133.0            84.0
# 145590       60.0        60.0          60.00        120.0             2.0
# 145582       60.0        60.0          60.00        120.0             2.0
# 145585       72.0        85.0          84.76      35854.0           423.0
# 145586       75.0        75.0          75.00      66150.0           882.0
# 145587       65.0        65.0          65.00      18720.0           288.0
# 145580       56.0        56.0          56.00       9688.0           173.0
#
#         Total_Kg_Sold  Stock_On_Hand       Date
# 56030            32.0            0.0 2019-12-11
# 56031           120.0            0.0 2019-12-11
# 144875         2816.0          300.0 2019-12-12
# 144874          352.0            6.0 2019-12-12
# 144873         1064.0          260.0 2019-12-12
# 144871         6072.0           32.0 2019-12-12
# 144872         3584.0            2.0 2019-12-12
# 144870         6976.0          637.0 2019-12-12
# 58744          1536.0          180.0 2019-12-14
# 58745           872.0            0.0 2019-12-14
# 58746           568.0          102.0 2019-12-14
# 58747             8.0            0.0 2019-12-14
# 58743           672.0          605.0 2019-12-14
# 58748           672.0           -8.0 2019-12-14
# 145590           16.0            0.0 2019-12-23
# 145582           16.0            0.0 2019-12-23
# 145585         3384.0            3.0 2019-12-23
# 145586         7056.0          131.0 2019-12-23
# 145587         2304.0          436.0 2019-12-23
# 145580         1384.0          371.0 2019-12-23

# %% [markdown]
# Based on the above table, it can be seen that multiple sales are taking place on the same day, which means that the data has to be consolidated to one day.

# %%
# Consolidation of repeated sales in a single day of the same product to one day
df = filtered_sales.groupby(['Province', 'Container', 'Size_Grade', 'Weight_Kg', 'Commodities', 'Date']
    )[['Low_Price', 'High_Price', 'Sales_Total', 'Total_Qty_Sold', 'Total_Kg_Sold', 'Stock_On_Hand']].agg(
        {
            'Low_Price':min,
            'High_Price':max,
            'Sales_Total':sum,
            'Total_Qty_Sold':sum,
            'Total_Kg_Sold':sum,
            'Stock_On_Hand':sum
        }
)

# %%
df
# Out:
#                                                                                      Low_Price  \
# Province          Container Size_Grade Weight_Kg Commodities             Date
#                   A8075                7.5       HABANERO YELLOW         2020-07-01      350.0
#                                                                          2020-07-08      350.0
#                                                                          2020-07-09      350.0
#                                                                          2020-07-14      350.0
#                                                                          2020-07-20      300.0
# ...                                                                                        ...
# WESTERN FREESTATE PP100     4M         10.0      POTATO LANORMA (WASHED) 2020-03-10        8.0
#                             4R         10.0      POTATO (WASHED) MONDIAL 2020-01-23        5.0
#                             4S         10.0      POTATO (WASHED) MONDIAL 2020-01-23        5.0
#                                                                          2020-06-19        5.0
#                             4Z         10.0      POTATO (WASHED) MONDIAL 2020-06-19       20.0
#
#                                                                                      High_Price  \
# Province          Container Size_Grade Weight_Kg Commodities             Date
#                   A8075                7.5       HABANERO YELLOW         2020-07-01       350.0
#                                                                          2020-07-08       350.0
#                                                                          2020-07-09       350.0
#                                                                          2020-07-14       350.0
#                                                                          2020-07-20       320.0
# ...                                                                                         ...
# WESTERN FREESTATE PP100     4M         10.0      POTATO LANORMA (WASHED) 2020-03-10        10.0
#                             4R         10.0      POTATO (WASHED) MONDIAL 2020-01-23        10.0
#                             4S         10.0      POTATO (WASHED) MONDIAL 2020-01-23         5.0
#                                                                          2020-06-19         5.0
#                             4Z         10.0      POTATO (WASHED) MONDIAL 2020-06-19        20.0
#
#                                                                                      Sales_Total  \
# Province          Container Size_Grade Weight_Kg Commodities             Date
#                   A8075                7.5       HABANERO YELLOW         2020-07-01        700.0
#                                                                          2020-07-08       1400.0
#                                                                          2020-07-09       1400.0
#                                                                          2020-07-14       1050.0
#                                                                          2020-07-20        620.0
# ...                                                                                          ...
# WESTERN FREESTATE PP100     4M         10.0      POTATO LANORMA (WASHED) 2020-03-10       1080.0
#                             4R         10.0      POTATO (WASHED) MONDIAL 2020-01-23       5470.0
#                             4S         10.0      POTATO (WASHED) MONDIAL 2020-01-23       1440.0
#                                                                          2020-06-19        835.0
#                             4Z         10.0      POTATO (WASHED) MONDIAL 2020-06-19         20.0
#
#                                                                                      Total_Qty_Sold  \
# Province          Container Size_Grade Weight_Kg Commodities             Date
#                   A8075                7.5       HABANERO YELLOW         2020-07-01             2.0
#                                                                          2020-07-08             4.0
#                                                                          2020-07-09             4.0
#                                                                          2020-07-14             3.0
#                                                                          2020-07-20             2.0
# ...                                                                                             ...
# WESTERN FREESTATE PP100     4M         10.0      POTATO LANORMA (WASHED) 2020-03-10           130.0
#                             4R         10.0      POTATO (WASHED) MONDIAL 2020-01-23          1049.0
#                             4S         10.0      POTATO (WASHED) MONDIAL 2020-01-23           288.0
#                                                                          2020-06-19           167.0
#                             4Z         10.0      POTATO (WASHED) MONDIAL 2020-06-19             1.0
#
#                                                                                      Total_Kg_Sold  \
# Province          Container Size_Grade Weight_Kg Commodities             Date
#                   A8075                7.5       HABANERO YELLOW         2020-07-01           15.0
#                                                                          2020-07-08           30.0
#                                                                          2020-07-09           30.0
#                                                                          2020-07-14           22.5
#                                                                          2020-07-20           15.0
# ...                                                                                            ...
# WESTERN FREESTATE PP100     4M         10.0      POTATO LANORMA (WASHED) 2020-03-10         1300.0
#                             4R         10.0      POTATO (WASHED) MONDIAL 2020-01-23        10490.0
#                             4S         10.0      POTATO (WASHED) MONDIAL 2020-01-23         2880.0
#                                                                          2020-06-19         1670.0
#                             4Z         10.0      POTATO (WASHED) MONDIAL 2020-06-19           10.0
#
#                                                                                      Stock_On_Hand
# Province          Container Size_Grade Weight_Kg Commodities             Date
#                   A8075                7.5       HABANERO YELLOW         2020-07-01            6.0
#                                                                          2020-07-08           12.0
#                                                                          2020-07-09           12.0
#                                                                          2020-07-14            2.0
#                                                                          2020-07-20            0.0
# ...                                                                                            ...
# WESTERN FREESTATE PP100     4M         10.0      POTATO LANORMA (WASHED) 2020-03-10            0.0
#                             4R         10.0      POTATO (WASHED) MONDIAL 2020-01-23            0.0
#                             4S         10.0      POTATO (WASHED) MONDIAL 2020-01-23            0.0
#                                                                          2020-06-19            0.0
#                             4Z         10.0      POTATO (WASHED) MONDIAL 2020-06-19          103.0
#
# [90560 rows x 6 columns]

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#   Province Container Size_Grade  Weight_Kg      Commodities       Date  \
# 0              A8075                   7.5  HABANERO YELLOW 2020-07-01
# 1              A8075                   7.5  HABANERO YELLOW 2020-07-08
# 2              A8075                   7.5  HABANERO YELLOW 2020-07-09
# 3              A8075                   7.5  HABANERO YELLOW 2020-07-14
# 4              A8075                   7.5  HABANERO YELLOW 2020-07-20
#
#    Low_Price  High_Price  Sales_Total  Total_Qty_Sold  Total_Kg_Sold  \
# 0      350.0       350.0        700.0             2.0           15.0
# 1      350.0       350.0       1400.0             4.0           30.0
# 2      350.0       350.0       1400.0             4.0           30.0
# 3      350.0       350.0       1050.0             3.0           22.5
# 4      300.0       320.0        620.0             2.0           15.0
#
#    Stock_On_Hand
# 0            6.0
# 1           12.0
# 2           12.0
# 3            2.0
# 4            0.0

# %%
df['avg_price_per_kg'] = round(df['Sales_Total'] / df['Total_Kg_Sold'], 2)
df['low_price_per_kg'] = round(df['Low_Price'] / df['Weight_Kg'], 2)
df['high_price_per_kg'] = round(df['High_Price'] / df['Weight_Kg'], 2)

# %%
df.head()
# Out:
#   Province Container Size_Grade  Weight_Kg      Commodities       Date  \
# 0              A8075                   7.5  HABANERO YELLOW 2020-07-01
# 1              A8075                   7.5  HABANERO YELLOW 2020-07-08
# 2              A8075                   7.5  HABANERO YELLOW 2020-07-09
# 3              A8075                   7.5  HABANERO YELLOW 2020-07-14
# 4              A8075                   7.5  HABANERO YELLOW 2020-07-20
#
#    Low_Price  High_Price  Sales_Total  Total_Qty_Sold  Total_Kg_Sold  \
# 0      350.0       350.0        700.0             2.0           15.0
# 1      350.0       350.0       1400.0             4.0           30.0
# 2      350.0       350.0       1400.0             4.0           30.0
# 3      350.0       350.0       1050.0             3.0           22.5
# 4      300.0       320.0        620.0             2.0           15.0
#
#    Stock_On_Hand  avg_price_per_kg  low_price_per_kg  high_price_per_kg
# 0            6.0             46.67             46.67              46.67
# 1           12.0             46.67             46.67              46.67
# 2           12.0             46.67             46.67              46.67
# 3            2.0             46.67             46.67              46.67
# 4            0.0             41.33             40.00              42.67

# %%
# Check which product is regularly sold based on the days in the data
day_count = sales['Date'].nunique()
df.groupby(['Province', 'Container', 'Size_Grade', 'Weight_Kg', 'Commodities'])['Commodities'].value_counts().apply(lambda x: x / day_count).sort_values(ascending=False)
# Out:
# Province  Container  Size_Grade  Weight_Kg  Commodities             Commodities
# CAPE      EC120      1S          12.0       APPLE GOLDEN DELICIOUS  APPLE GOLDEN DELICIOUS    1.000000
# NATAL     ST170                  17.0       CHILLIES GREEN          CHILLIES GREEN            0.986395
#           NE005                  0.5        CURRY LEAVES            CURRY LEAVES              0.986395
#           BI100                  10.0       BRINJALS                BRINJALS                  0.986395
#           AT200                  20.0       CABBAGE                 CABBAGE                   0.986395
#                                                                                                 ...
#           BF070      1L          7.0        CUCUMBERS ENGLISH       CUCUMBERS ENGLISH         0.006803
#                                             LEMON                   LEMON                     0.006803
#                      1M          7.0        CUCUMBERS ENGLISH       CUCUMBERS ENGLISH         0.006803
#                      2L          7.0        LEMON                   LEMON                     0.006803
#           BV150      1S          15.0       SATSUMAS                SATSUMAS                  0.006803
# Name: Commodities, Length: 6026, dtype: float64

# %% [markdown]
# Based on the results above, **APPLE GOLDEN DELICIOUS** has been sold for every day that is recorded in the database. For this notebook, this product will be used as a template for developing a forecasting model.

# %%
filtered_df = df[
    (df['Commodities'] == 'APPLE GOLDEN DELICIOUS') & 
    (df['Weight_Kg'] == 12.0) &
    (df['Size_Grade'] == '1S') &
    (df['Container'] == 'EC120') &
    (df['Province'] == 'CAPE')
]

# %%
filtered_df.head()
# Out:
#      Province Container Size_Grade  Weight_Kg             Commodities  \
# 4350     CAPE     EC120         1S       12.0  APPLE GOLDEN DELICIOUS
# 4351     CAPE     EC120         1S       12.0  APPLE GOLDEN DELICIOUS
# 4352     CAPE     EC120         1S       12.0  APPLE GOLDEN DELICIOUS
# 4353     CAPE     EC120         1S       12.0  APPLE GOLDEN DELICIOUS
# 4354     CAPE     EC120         1S       12.0  APPLE GOLDEN DELICIOUS
#
#            Date  Low_Price  High_Price  Sales_Total  Total_Qty_Sold  \
# 4350 2019-12-11       50.0       140.0       3840.0            33.0
# 4351 2019-12-12      100.0       144.0     129546.0          1151.0
# 4352 2019-12-14      100.0       140.0       7734.0            63.0
# 4353 2019-12-23       40.0       200.0      99673.0          1519.0
# 4354 2019-12-30       50.0       140.0      69874.0           892.0
#
#       Total_Kg_Sold  Stock_On_Hand  avg_price_per_kg  low_price_per_kg  \
# 4350          396.0         1117.0              9.70              4.17
# 4351        13812.0         2070.0              9.38              8.33
# 4352          756.0         2865.0             10.23              8.33
# 4353        18228.0         6017.0              5.47              3.33
# 4354        10704.0         1272.0              6.53              4.17
#
#       high_price_per_kg
# 4350              11.67
# 4351              12.00
# 4352              11.67
# 4353              16.67
# 4354              11.67

# %%
apples = filtered_df[[
    'Province', 'Date', 'Low_Price', 'High_Price', 'Sales_Total', 'Total_Qty_Sold',
    'Total_Kg_Sold', 'Stock_On_Hand', 'avg_price_per_kg', 'low_price_per_kg', 'high_price_per_kg'
]]

# %%
# Check for multicollinearity
sns.heatmap(apples.corr(), annot=True, cbar=False);

# %% [markdown]
# Excluding the average prices per kg, there's high correlation between **Sales_Total, Total_Qty_Sold** and **Total_Kg_Sold**. For determining inventory levels, only **Total_Qty_Sold** will remain.

# %%
apples = apples[['Date', 'Total_Qty_Sold', 'Stock_On_Hand', 
                 'avg_price_per_kg', 'low_price_per_kg', 'high_price_per_kg']]

# %%
apples.head()
# Out:
#            Date  Total_Qty_Sold  Stock_On_Hand  avg_price_per_kg  \
# 4350 2019-12-11            33.0         1117.0              9.70
# 4351 2019-12-12          1151.0         2070.0              9.38
# 4352 2019-12-14            63.0         2865.0             10.23
# 4353 2019-12-23          1519.0         6017.0              5.47
# 4354 2019-12-30           892.0         1272.0              6.53
#
#       low_price_per_kg  high_price_per_kg
# 4350              4.17              11.67
# 4351              8.33              12.00
# 4352              8.33              11.67
# 4353              3.33              16.67
# 4354              4.17              11.67

# %%
apples['weekday'] = filtered_df['Date'].apply(lambda x: x.day_name())

# %%
#apples.head()

# %%
apples.sort_values('Date', inplace=True)

# %%
#apples.head()

# %%
apples['month'] = apples['Date'].apply(lambda x: x.month_name())

# %%
#apples.head()

# %%
def season(month):
    """
    Returns the season of which the month falls in
    
    Parameters
    -----------
    month: str
        The month of the year as a full month name
    
    Returns
    --------
    str:
        The season of the year
        
    Examples
    ---------
    >>> season('October')
    'spring'
    """
    
    # Seasons
    summer = ['December', 'January', 'February']
    autumn = ['March', 'April', 'May']
    winter = ['June', 'July', 'August']
    spring = ['September', 'October', 'November']
    
    if month in summer:
        return 'summer'
    elif month in autumn:
        return 'autumn'
    elif month in winter:
        return 'winter'
    else:
        return 'spring'

# %%
apples['season'] = apples['month'].apply(season)

# %%
apples.head()
# Out:
#            Date  Total_Qty_Sold  Stock_On_Hand  avg_price_per_kg  \
# 4350 2019-12-11            33.0         1117.0              9.70
# 4351 2019-12-12          1151.0         2070.0              9.38
# 4352 2019-12-14            63.0         2865.0             10.23
# 4353 2019-12-23          1519.0         6017.0              5.47
# 4354 2019-12-30           892.0         1272.0              6.53
#
#       low_price_per_kg  high_price_per_kg    weekday     month  season
# 4350              4.17              11.67  Wednesday  December  summer
# 4351              8.33              12.00   Thursday  December  summer
# 4352              8.33              11.67   Saturday  December  summer
# 4353              3.33              16.67     Monday  December  summer
# 4354              4.17              11.67     Monday  December  summer

# %%
apples['weekday'].value_counts()
# Out:
# Wednesday    31
# Thursday     29
# Monday       28
# Tuesday      26
# Friday       17
# Saturday     16
# Name: weekday, dtype: int64

# %%
apples['season'].value_counts()
# Out:
# winter    52
# autumn    44
# summer    38
# spring    13
# Name: season, dtype: int64

# %%
plt.figure(figsize=(16,5))
sns.swarmplot(x='season', y='avg_price_per_kg', data=apples)
plt.title("Price variations of Apples Golden Delicious");

# %%
apples['week_of_year'] = apples['Date'].apply(lambda x: x.week)

# %%
#apples.head()

# %%
apples['is_month_end'] = apples['Date'].apply(lambda x: 1 if x.day in range(25,32) else 0)

# %%
#apples.head()

# %%
apples['is_month_end'].value_counts()
# Out:
# 0    118
# 1     29
# Name: is_month_end, dtype: int64

# %%
apples['range'] = apples['high_price_per_kg'] - apples['low_price_per_kg']

# %%
apples.head()
# Out:
#            Date  Total_Qty_Sold  Stock_On_Hand  avg_price_per_kg  \
# 4350 2019-12-11            33.0         1117.0              9.70
# 4351 2019-12-12          1151.0         2070.0              9.38
# 4352 2019-12-14            63.0         2865.0             10.23
# 4353 2019-12-23          1519.0         6017.0              5.47
# 4354 2019-12-30           892.0         1272.0              6.53
#
#       low_price_per_kg  high_price_per_kg    weekday     month  season  \
# 4350              4.17              11.67  Wednesday  December  summer
# 4351              8.33              12.00   Thursday  December  summer
# 4352              8.33              11.67   Saturday  December  summer
# 4353              3.33              16.67     Monday  December  summer
# 4354              4.17              11.67     Monday  December  summer
#
#       week_of_year  is_month_end  range
# 4350            50             0   7.50
# 4351            50             0   3.67
# 4352            50             0   3.34
# 4353            52             0  13.34
# 4354             1             1   7.50

# %%
df = apples[['avg_price_per_kg', 'weekday', 'month', 'season', 'is_month_end', 'range']]

# %%
df['range'] = df['range'].shift(periods=-1)

# %%
df.tail()
# Out:
#       avg_price_per_kg    weekday      month  season  is_month_end  range
# 4492              7.70     Monday  September  spring             0   4.17
# 4493              7.39  Wednesday  September  spring             0   5.16
# 4494              6.64     Monday  September  spring             1   1.33
# 4495              7.33   Thursday    October  spring             0   3.33
# 4496              8.04   Saturday    October  spring             0    NaN

# %%
# Drop the last row since column values were shifted up by 1 period
df.dropna(inplace=True)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()
# Out:
#       avg_price_per_kg  is_month_end  range  weekday_Monday  weekday_Saturday  \
# 4350              9.70             0   3.67               0                 0
# 4351              9.38             0   3.34               0                 0
# 4352             10.23             0  13.34               0                 1
# 4353              5.47             0   7.50               1                 0
# 4354              6.53             1   6.50               1                 0
#
#       weekday_Thursday  weekday_Tuesday  weekday_Wednesday  month_August  \
# 4350                 0                0                  1             0
# 4351                 1                0                  0             0
# 4352                 0                0                  0             0
# 4353                 0                0                  0             0
# 4354                 0                0                  0             0
#
#       month_December  ...  month_January  month_July  month_June  month_March  \
# 4350               1  ...              0           0           0            0
# 4351               1  ...              0           0           0            0
# 4352               1  ...              0           0           0            0
# 4353               1  ...              0           0           0            0
# 4354               1  ...              0           0           0            0
#
#       month_May  month_October  month_September  season_spring  season_summer  \
# 4350          0              0                0              0              1
# 4351          0              0                0              0              1
# 4352          0              0                0              0              1
# 4353          0              0                0              0              1
# 4354          0              0                0              0              1
#
#       season_winter
# 4350              0
# 4351              0
# 4352              0
# 4353              0
# 4354              0
#
# [5 rows x 21 columns]

# %%
X = df.iloc[:,1:]
y = df['avg_price_per_kg']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False, random_state=42)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predict = lr.predict(X_test)

# %%
predict_df = pd.DataFrame({'actual':y_test.values, 'predict':predict}, index=range(len(y_test)))

# %%
ax = predict_df.plot(figsize=(12,6))
ax.autoscale(axis='x', tight=True)
ax.set(ylabel='avg price per kg')
plt.title("average price per kg of apples");
